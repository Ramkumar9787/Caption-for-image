# %% [markdown]
# # Image Captioning
# ## Introduction
# This assignment aims to describe the content of an image by using CNNs and RNNs to build an Image Caption Generator. The model would be based on the paper [4] and it will be implemented using Tensorflow and Keras. The dataset used is Flickr 8K [5], consisting of 8,000 images each one paired with five different captions to provide clear descriptions.
#
# The model architectures consists of a CNN which extracts the features and encodes the input image and a Recurrent Neural Network (RNN) based on Long Short Term Memory (LSTM) layers. The most significant difference with other models is that the image embedding is provided as the first input to the RNN network and only once.
# ![Model Architecture](https://github.com/raunak222/Image-Captioning/raw/master/Image/decoder.png)
#
#
# ## References
# [1] Image captioning with visual attention: https://www.tensorflow.org/tutorials/text/image_captioning
#
# [2] RNNs in Computer Vision — Image captioning: https://thinkautonomous.medium.com/rnns-in-computer-vision-image-captioning-597d5e1321d1
#
# [3] Image Captioning Project from Udacity Computer Vision Nanodegree: https://github.com/raunak222/Image-Captioning
#
# [4] Show and Tell: A Neural Image Caption Generator: https://arxiv.org/pdf/1411.4555.pdf
#
# [5] Flickr 8k Dataset: https://www.kaggle.com/adityajn105/flickr8k
#
# ## Authors
# - Serghei Socolovschi: [serghei@kth.se](mailto:serghei@kth.se)
# - Angel Igareta: [alih2@kth.se](mailto:alih2@kth.se)

# %% [markdown]
# ## Dependencies

# %%
import re
import random

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from time import time

from tqdm import tqdm # progress bar
from sklearn.model_selection import train_test_split # Dividing train test
from nltk.translate.bleu_score import corpus_bleu # BLEU Score

# %% [markdown]
# ## Dataset
# Load dataset from local path or google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Change this path to the dataset downloaded from Flickr8 [5]
dataset_path = "/content/drive/MyDrive/datasets"
dataset_images_path = "/content/drive/MyDrive/datasets/Images/"

# %%
img_height = 180
img_width = 180
validation_split = 0.2

# %% [markdown]
# ### Encoder Model
#
# In order to extract the features from the images, a pretrained CNN model, named Inception V3 was used. In the figure below, there is the representation of the architecture of the used network.
#
# ![Inception Architecture](https://paperswithcode.com/media/methods/inceptionv3onc--oview_vjAbOfw.png)

# %%
# Remove the last layer of the Inception V3 model
def get_encoder():
    image_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')
    new_input = image_model.input
    hidden_layer = image_model.layers[-1].output

    image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
    return image_features_extract_model

# %% [markdown]
# ### Read captions
# Create dictionary with picture filename as the key and an array of captions as the value

# %%
# Preprocess the caption, splitting the string and adding <start> and <end> tokens
def get_preprocessed_caption(caption):
    caption = re.sub(r'\s+', ' ', caption)
    caption = caption.strip()
    caption = "<start> " + caption + " <end>"
    return caption

# %%
images_captions_dict = {}

with open("/content/drive/MyDrive/datasets/captions.txt", "r") as dataset_info:
    next(dataset_info) # Omit header: image, caption

    # Using a subset of 4,000 entries out of 40,000
    for info_raw in list(dataset_info)[:4000]:
        info = info_raw.split(",")
        image_filename = info[0]
        caption = get_preprocessed_caption(info[1])

        if image_filename not in images_captions_dict.keys():
            images_captions_dict[image_filename] = [caption]
        else:
            images_captions_dict[image_filename].append(caption)

# %% [markdown]
# ### Read images
# Create dictionary with image filename as key and the image feature extracted using the pretrained model as the value.

# %%
def load_image(image_path):
    img = tf.io.read_file(dataset_images_path + image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (img_height, img_width))
    img = tf.keras.applications.inception_v3.preprocess_input(img) # preprocessing needed for pre-trained model
    return img, image_path

# %%
image_captions_dict_keys = list(images_captions_dict.keys())
image_dataset = tf.data.Dataset.from_tensor_slices(image_captions_dict_keys)
image_dataset = image_dataset.map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(64)

# %%
images_dict = {}
encoder = get_encoder()
for img_tensor, path_tensor in tqdm(image_dataset):
    batch_features_tensor = encoder(img_tensor)

    # Loop over batch to save each element in images_dict
    for batch_features, path in zip(batch_features_tensor, path_tensor):
        decoded_path = path.numpy().decode("utf-8")
        images_dict[decoded_path] = batch_features.numpy()
# Out:
# 100%|██████████| 13/13 [00:05<00:00,  2.54it/s]

# %% [markdown]
# Image size after extracting features from the pre-trained model

# %%
list(images_dict.items())[0][1].shape
# Out:
# (4, 4, 2048)

# %% [markdown]
# Display image from original dataset

# %%
plt.imshow(load_image("1000268201_693b08cb0e.jpg")[0].numpy())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Get images and labels from filenames

# %%
def get_images_labels(image_filenames):
    images = []
    labels = []

    for image_filename in image_filenames:
        image = images_dict[image_filename]
        captions = images_captions_dict[image_filename]

        # Add one instance per caption
        for caption in captions:
            images.append(image)
            labels.append(caption)

    return images, labels

# %% [markdown]
# ### Generate train and test set
# This approach divides image_filenames, to avoid same image with different caption in train and test dataset. Also the resulting train test is not shuffled because a tensorflow native method will be used for that aim.

# %%
image_filenames = list(images_captions_dict.keys())
image_filenames_train, image_filenames_test = \
    train_test_split(image_filenames, test_size=validation_split, random_state=1)

X_train, y_train_raw = get_images_labels(image_filenames_train)
X_test, y_test_raw = get_images_labels(image_filenames_test)

# %%
# Per image 5 captions and 0.2 test split
len(X_train), len(y_train_raw), len(X_test), len(y_test_raw)
# Out:
# (3200, 3200, 800, 800)

# %% [markdown]
# ### Tokenize train labels
# Generate a vocabulary and transform the train captions to a vector with their indices in the vocabulary [1].

# %%
top_k = 5000 # Take maximum of words out of 7600
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')

# Generate vocabulary from train captions
tokenizer.fit_on_texts(y_train_raw)

# Introduce padding to make the captions of the same size for the LSTM model
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# Create the tokenized vectors
y_train = tokenizer.texts_to_sequences(y_train_raw)

# Add padding to each vector to the max_length of the captions (automatically done)
y_train = tf.keras.preprocessing.sequence.pad_sequences(y_train, padding='post')

# %% [markdown]
# Calculate max caption length which would be the number of hidden layers in the LSTM.

# %%
max_caption_length = max(len(t) for t in y_train)
print(max_caption_length)
# Out:
# 35

# %% [markdown]
# Example tokenization

# %%
[tokenizer.index_word[i] for i in y_train[1]]
# Out:
# ['<start>',
#  'a',
#  'black',
#  'dog',
#  'is',
#  'standing',
#  'on',
#  'a',
#  'step',
#  'next',
#  'to',
#  'a',
#  'river',
#  'at',
#  'it',
#  'shakes',
#  'itself',
#  'dry',
#  '<end>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>']

# %% [markdown]
# ### Generate Tensorflow dataset
# Generate dataset using buffer and batch size that would be used during training.

# %%
  dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))

# %%
BUFFER_SIZE = len(X_train)
BATCH_SIZE = 64
NUM_STEPS = BUFFER_SIZE // BATCH_SIZE

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# Using prefetching: https://www.tensorflow.org/guide/data_performance#prefetching
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Models Definition

# %% [markdown]
# ### CNN Encoder

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it using pickle
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.flat = tf.keras.layers.Flatten()
        self.fc = tf.keras.layers.Dense(embedding_dim) #, activation='relu')

    def call(self, x):
        x = self.flat(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ### RNN Decoder

# %%
class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        # input_dim = size of the vocabulary
        # Define the embedding layer to transform the input caption sequence
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

        # Define the Long Short Term Memory layer to predict the next words in the sequence
        self.lstm = tf.keras.layers.LSTM(self.units, return_sequences=True, return_state=True)

        # Define a dense layer to transform the LSTM output into prediction of the best word
        self.fc = tf.keras.layers.Dense(vocab_size) #, activation='softmax')

    # A function that transforms the input embeddings and passes them to the LSTM layer
    def call(self, captions, features, omit_features = False, initial_state = None, verbose = False):
        if verbose:
            print("Before embedding")
            print(captions.shape)

        embed = self.embedding(captions) #(batch_size, 1, embedding_dim)

        if verbose:
            print("Embed")
            print(embed.shape)

        features = tf.expand_dims(features, 1)

        if verbose:
            print("Features")
            print(features.shape)

        # Concatenating the image and caption embeddings before providing them to LSTM
        # shape == (batch_size, 1, embedding_dim + hidden_size)
        lstm_input = tf.concat([features, embed], axis=-2) if (omit_features == False) else embed

        if verbose:
            print("LSTM input")
            print(lstm_input.shape)

        # Passing the concatenated vector to the LSTM
        output, memory_state, carry_state = self.lstm(lstm_input, initial_state=initial_state)

        if verbose:
            print("LSTM output")
            print(output.shape)

        # Transform LSTM output units to vocab_size
        output = self.fc(output)

        return output, memory_state, carry_state

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %% [markdown]
# ## Train Stage

# %%
units = embedding_dim = 512 # As in the paper
vocab_size = min(top_k + 1, len(tokenizer.word_index.keys()))

# Initialize encoder and decoder
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# Initialize optimizer
optimizer = tf.keras.optimizers.Adam()

# As the label is not one-hot encoded but indices. Logits as they are not probabilities.
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# Computes the loss using SCCE and calculates the average of singular losses in the tensor
def loss_function(real, pred, verbose=False):
    loss_ = loss_object(real, pred)

    if verbose:
        print("Loss")
        print(loss_)

    loss_ = tf.reduce_mean(loss_, axis = 1)

    if verbose:
        print("After Mean Axis 1")
        print(loss_)

    return loss_

# %%
# Key Point: Any Python side-effects (appending to a list, printing with print, etc) will only happen once, when func is traced.
# To have side-effects executed into your tf.function they need to be written as TF ops:
@tf.function
def train_step(img_tensor, target, verbose=False):
    if verbose:
        print("Image tensor")
        print(img_tensor.shape)

        print("Target")
        print(target.shape)

    # The input would be each set of words without the last one (<end>), to leave space for the first one that
    # would be the image embedding
    dec_input = tf.convert_to_tensor(target[:, :-1])

    # Source: https://www.tensorflow.org/api_docs/python/tf/GradientTape
    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        if verbose:
            print("Features CNN")
            print(features)

        predictions, _, _ = decoder(dec_input, features, verbose=verbose)

        if verbose:
            print("Predictions RNN")
            print(predictions)

        caption_loss = loss_function(target, predictions) # (batch_size, )

        # After tape
        total_batch_loss = tf.reduce_sum(caption_loss) # Sum (batch_size, ) => K
        mean_batch_loss = tf.reduce_mean(caption_loss) # Mean(batch_size, ) => K

    # Updated the variables
    trainable_variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(caption_loss, trainable_variables)
    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return total_batch_loss, mean_batch_loss

# %% [markdown]
# ### Checkpoint
# Create a tensorflow checkpoint on a local path to save the encoder and decoder state while training. Only the last 5 models would be saved.

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # restoring the latest checkpoint in checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# ### Start Training

# %%
loss_plot = []

# %%
EPOCHS = 100
start_epoch = 0

for epoch in range(start_epoch, EPOCHS):
    real_epoch = len(loss_plot) + 1
    start = time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        total_batch_loss, mean_batch_loss = train_step(img_tensor, target, verbose=False)
        total_loss += total_batch_loss

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Batch Loss {:.4f}'.format(real_epoch, batch, mean_batch_loss.numpy()))

    print ('Total Loss {:.6f}'.format(total_loss))
    epoch_loss = total_loss / NUM_STEPS

    # storing the epoch end loss value to plot later
    loss_plot.append(epoch_loss)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print ('Epoch {} Epoch Loss {:.6f}'.format(real_epoch, epoch_loss))
    print ('Time taken for 1 epoch {} sec\n'.format(time() - start))
# Out:
# Epoch 1 Batch 0 Batch Loss 0.1373
# Total Loss 467.402588
# Epoch 1 Epoch Loss 9.348052
# Time taken for 1 epoch 10.714540958404541 sec
#
# Epoch 2 Batch 0 Batch Loss 0.1353
# Total Loss 460.669037
# Epoch 2 Epoch Loss 9.213381
# Time taken for 1 epoch 2.2447030544281006 sec
#
# Epoch 3 Batch 0 Batch Loss 0.1342
# Total Loss 458.873627
# Epoch 3 Epoch Loss 9.177472
# Time taken for 1 epoch 1.5533571243286133 sec
#
# Epoch 4 Batch 0 Batch Loss 0.1391
# Total Loss 461.384644
# Epoch 4 Epoch Loss 9.227693
# Time taken for 1 epoch 1.2185635566711426 sec
#
# Epoch 5 Batch 0 Batch Loss 0.1369
# Total Loss 462.870422
# Epoch 5 Epoch Loss 9.257408
# Time taken for 1 epoch 1.3998072147369385 sec
#
# Epoch 6 Batch 0 Batch Loss 0.1389
# Total Loss 466.852051
# Epoch 6 Epoch Loss 9.337041
# Time taken for 1 epoch 2.3208322525024414 sec
#
# Epoch 7 Batch 0 Batch Loss 0.1331
# Total Loss 467.245728
# Epoch 7 Epoch Loss 9.344914
# Time taken for 1 epoch 1.848454475402832 sec
#
# Epoch 8 Batch 0 Batch Loss 0.1468
# Total Loss 474.630981
# Epoch 8 Epoch Loss 9.492620
# Time taken for 1 epoch 2.544779062271118 sec
#
# Epoch 9 Batch 0 Batch Loss 0.1356
# Total Loss 461.162170
# Epoch 9 Epoch Loss 9.223244
# Time taken for 1 epoch 1.2717130184173584 sec
#
# Epoch 10 Batch 0 Batch Loss 0.1396
# Total Loss 472.075287
# Epoch 10 Epoch Loss 9.441505
# Time taken for 1 epoch 1.1434786319732666 sec
#
# Epoch 11 Batch 0 Batch Loss 0.1393
# Total Loss 472.898621
# Epoch 11 Epoch Loss 9.457973
# Time taken for 1 epoch 1.9418416023254395 sec
#
# Epoch 12 Batch 0 Batch Loss 0.1307
# Total Loss 463.285217
# Epoch 12 Epoch Loss 9.265704
# Time taken for 1 epoch 1.1366169452667236 sec
#
# Epoch 13 Batch 0 Batch Loss 0.1367
# Total Loss 465.860199
# Epoch 13 Epoch Loss 9.317204
# Time taken for 1 epoch 1.2680764198303223 sec
#
# Epoch 14 Batch 0 Batch Loss 0.1338
# Total Loss 462.761475
# Epoch 14 Epoch Loss 9.255230
# Time taken for 1 epoch 1.1288022994995117 sec
#
# Epoch 15 Batch 0 Batch Loss 0.1352
# Total Loss 462.537506
# Epoch 15 Epoch Loss 9.250751
# Time taken for 1 epoch 1.1902756690979004 sec
#
# Epoch 16 Batch 0 Batch Loss 0.1326
# Total Loss 459.339722
# Epoch 16 Epoch Loss 9.186794
# Time taken for 1 epoch 2.206655502319336 sec
#
# Epoch 17 Batch 0 Batch Loss 0.1374
# Total Loss 455.448364
# Epoch 17 Epoch Loss 9.108967
# Time taken for 1 epoch 1.2966604232788086 sec
#
# Epoch 18 Batch 0 Batch Loss 0.1372
# Total Loss 460.240875
# Epoch 18 Epoch Loss 9.204818
# Time taken for 1 epoch 1.1298770904541016 sec
#
# Epoch 19 Batch 0 Batch Loss 0.1453
# Total Loss 466.701019
# Epoch 19 Epoch Loss 9.334021
# Time taken for 1 epoch 1.187765121459961 sec
#
# Epoch 20 Batch 0 Batch Loss 0.1336
# Total Loss 469.244690
# Epoch 20 Epoch Loss 9.384893
# Time taken for 1 epoch 1.1825430393218994 sec
#
# Epoch 21 Batch 0 Batch Loss 0.1336
# Total Loss 458.035339
# Epoch 21 Epoch Loss 9.160707
# Time taken for 1 epoch 2.2115142345428467 sec
#
# Epoch 22 Batch 0 Batch Loss 0.1271
# Total Loss 453.969299
# Epoch 22 Epoch Loss 9.079386
# Time taken for 1 epoch 1.11448335647583 sec
#
# Epoch 23 Batch 0 Batch Loss 0.1359
# Total Loss 452.693817
# Epoch 23 Epoch Loss 9.053876
# Time taken for 1 epoch 1.2410905361175537 sec
#
# Epoch 24 Batch 0 Batch Loss 0.1300
# Total Loss 458.359222
# Epoch 24 Epoch Loss 9.167185
# Time taken for 1 epoch 1.2510206699371338 sec
#
# Epoch 25 Batch 0 Batch Loss 0.1388
# Total Loss 447.697876
# Epoch 25 Epoch Loss 8.953958
# Time taken for 1 epoch 1.132369041442871 sec
#
# Epoch 26 Batch 0 Batch Loss 0.1339
# Total Loss 450.483368
# Epoch 26 Epoch Loss 9.009667
# Time taken for 1 epoch 2.1752066612243652 sec
#
# Epoch 27 Batch 0 Batch Loss 0.1261
# Total Loss 453.137390
# Epoch 27 Epoch Loss 9.062748
# Time taken for 1 epoch 1.2119526863098145 sec
#
# Epoch 28 Batch 0 Batch Loss 0.1370
# Total Loss 457.530884
# Epoch 28 Epoch Loss 9.150618
# Time taken for 1 epoch 1.1141726970672607 sec
#
# Epoch 29 Batch 0 Batch Loss 0.1305
# Total Loss 457.516785
# Epoch 29 Epoch Loss 9.150335
# Time taken for 1 epoch 1.1014621257781982 sec
#
# Epoch 30 Batch 0 Batch Loss 0.1409
# Total Loss 457.874908
# Epoch 30 Epoch Loss 9.157498
# Time taken for 1 epoch 1.1000356674194336 sec
#
# Epoch 31 Batch 0 Batch Loss 0.1269
# Total Loss 462.510864
# Epoch 31 Epoch Loss 9.250217
# Time taken for 1 epoch 2.178398609161377 sec
#
# Epoch 32 Batch 0 Batch Loss 0.1311
# Total Loss 456.764130
# Epoch 32 Epoch Loss 9.135283
# Time taken for 1 epoch 1.1048142910003662 sec
#
# Epoch 33 Batch 0 Batch Loss 0.1332
# Total Loss 472.017822
# Epoch 33 Epoch Loss 9.440356
# Time taken for 1 epoch 1.099693775177002 sec
#
# Epoch 34 Batch 0 Batch Loss 0.1345
# Total Loss 490.146118
# Epoch 34 Epoch Loss 9.802922
# Time taken for 1 epoch 1.1003096103668213 sec
#
# Epoch 35 Batch 0 Batch Loss 0.1467
# Total Loss 477.585297
# Epoch 35 Epoch Loss 9.551706
# Time taken for 1 epoch 1.1028449535369873 sec
#
# Epoch 36 Batch 0 Batch Loss 0.1322
# Total Loss 462.255035
# Epoch 36 Epoch Loss 9.245101
# Time taken for 1 epoch 2.042515754699707 sec
#
# Epoch 37 Batch 0 Batch Loss 0.1314
# Total Loss 449.367828
# Epoch 37 Epoch Loss 8.987356
# Time taken for 1 epoch 1.1215779781341553 sec
#
# Epoch 38 Batch 0 Batch Loss 0.1343
# Total Loss 443.564697
# Epoch 38 Epoch Loss 8.871294
# Time taken for 1 epoch 1.0937507152557373 sec
#
# Epoch 39 Batch 0 Batch Loss 0.1321
# Total Loss 449.085022
# Epoch 39 Epoch Loss 8.981701
# Time taken for 1 epoch 1.10154128074646 sec
#
# Epoch 40 Batch 0 Batch Loss 0.1306
# Total Loss 444.394897
# Epoch 40 Epoch Loss 8.887897
# Time taken for 1 epoch 1.0952422618865967 sec
#
# Epoch 41 Batch 0 Batch Loss 0.1284
# Total Loss 452.231812
# Epoch 41 Epoch Loss 9.044636
# Time taken for 1 epoch 1.8773105144500732 sec
#
# Epoch 42 Batch 0 Batch Loss 0.1366
# Total Loss 452.921936
# Epoch 42 Epoch Loss 9.058438
# Time taken for 1 epoch 1.0998308658599854 sec
#
# Epoch 43 Batch 0 Batch Loss 0.1422
# Total Loss 453.458160
# Epoch 43 Epoch Loss 9.069163
# Time taken for 1 epoch 1.0905168056488037 sec
#
# Epoch 44 Batch 0 Batch Loss 0.1395
# Total Loss 459.429871
# Epoch 44 Epoch Loss 9.188598
# Time taken for 1 epoch 1.0987255573272705 sec
#
# Epoch 45 Batch 0 Batch Loss 0.1321
# Total Loss 449.009430
# Epoch 45 Epoch Loss 8.980188
# Time taken for 1 epoch 1.0995514392852783 sec
#
# Epoch 46 Batch 0 Batch Loss 0.1317
# Total Loss 443.042511
# Epoch 46 Epoch Loss 8.860850
# Time taken for 1 epoch 1.9944524765014648 sec
#
# Epoch 47 Batch 0 Batch Loss 0.1256
# Total Loss 436.024597
# Epoch 47 Epoch Loss 8.720492
# Time taken for 1 epoch 1.1437883377075195 sec
#
# Epoch 48 Batch 0 Batch Loss 0.1298
# Total Loss 444.040100
# Epoch 48 Epoch Loss 8.880802
# Time taken for 1 epoch 1.1067225933074951 sec
#
# Epoch 49 Batch 0 Batch Loss 0.1294
# Total Loss 434.601990
# Epoch 49 Epoch Loss 8.692039
# Time taken for 1 epoch 1.0961658954620361 sec
#
# Epoch 50 Batch 0 Batch Loss 0.1271
# Total Loss 426.925232
# Epoch 50 Epoch Loss 8.538505
# Time taken for 1 epoch 1.0961048603057861 sec
#
# Epoch 51 Batch 0 Batch Loss 0.1147
# Total Loss 421.536743
# Epoch 51 Epoch Loss 8.430735
# Time taken for 1 epoch 1.8476130962371826 sec
#
# Epoch 52 Batch 0 Batch Loss 0.1262
# Total Loss 417.454712
# Epoch 52 Epoch Loss 8.349094
# Time taken for 1 epoch 1.0997343063354492 sec
#
# Epoch 53 Batch 0 Batch Loss 0.1265
# Total Loss 425.366547
# Epoch 53 Epoch Loss 8.507331
# Time taken for 1 epoch 1.096752405166626 sec
#
# Epoch 54 Batch 0 Batch Loss 0.1207
# Total Loss 422.729614
# Epoch 54 Epoch Loss 8.454593
# Time taken for 1 epoch 1.1032323837280273 sec
#
# Epoch 55 Batch 0 Batch Loss 0.1226
# Total Loss 423.662720
# Epoch 55 Epoch Loss 8.473254
# Time taken for 1 epoch 1.102362871170044 sec
#
# Epoch 56 Batch 0 Batch Loss 0.1325
# Total Loss 429.391174
# Epoch 56 Epoch Loss 8.587824
# Time taken for 1 epoch 1.9991846084594727 sec
#
# Epoch 57 Batch 0 Batch Loss 0.1273
# Total Loss 433.300537
# Epoch 57 Epoch Loss 8.666011
# Time taken for 1 epoch 1.264394760131836 sec
#
# Epoch 58 Batch 0 Batch Loss 0.1323
# Total Loss 429.935486
# Epoch 58 Epoch Loss 8.598710
# Time taken for 1 epoch 1.152479887008667 sec
#
# Epoch 59 Batch 0 Batch Loss 0.1243
# Total Loss 426.308716
# Epoch 59 Epoch Loss 8.526175
# Time taken for 1 epoch 1.106586217880249 sec
#
# Epoch 60 Batch 0 Batch Loss 0.1326
# Total Loss 428.880798
# Epoch 60 Epoch Loss 8.577616
# Time taken for 1 epoch 1.1118240356445312 sec
#
# Epoch 61 Batch 0 Batch Loss 0.1267
# Total Loss 431.765808
# Epoch 61 Epoch Loss 8.635316
# Time taken for 1 epoch 1.882897138595581 sec
#
# Epoch 62 Batch 0 Batch Loss 0.1261
# Total Loss 433.326508
# Epoch 62 Epoch Loss 8.666531
# Time taken for 1 epoch 1.1721515655517578 sec
#
# Epoch 63 Batch 0 Batch Loss 0.1296
# Total Loss 430.327606
# Epoch 63 Epoch Loss 8.606552
# Time taken for 1 epoch 1.1129367351531982 sec
#
# Epoch 64 Batch 0 Batch Loss 0.1244
# Total Loss 433.374298
# Epoch 64 Epoch Loss 8.667486
# Time taken for 1 epoch 1.1086862087249756 sec
#
# Epoch 65 Batch 0 Batch Loss 0.1224
# Total Loss 434.330963
# Epoch 65 Epoch Loss 8.686619
# Time taken for 1 epoch 1.107398271560669 sec
#
# Epoch 66 Batch 0 Batch Loss 0.1345
# Total Loss 428.151733
# Epoch 66 Epoch Loss 8.563035
# Time taken for 1 epoch 2.256232261657715 sec
#
# Epoch 67 Batch 0 Batch Loss 0.1220
# Total Loss 424.768921
# Epoch 67 Epoch Loss 8.495378
# Time taken for 1 epoch 1.2952053546905518 sec
#
# Epoch 68 Batch 0 Batch Loss 0.1271
# Total Loss 423.261566
# Epoch 68 Epoch Loss 8.465231
# Time taken for 1 epoch 1.144880771636963 sec
#
# Epoch 69 Batch 0 Batch Loss 0.1256
# Total Loss 423.521851
# Epoch 69 Epoch Loss 8.470437
# Time taken for 1 epoch 1.1059141159057617 sec
#
# Epoch 70 Batch 0 Batch Loss 0.1257
# Total Loss 425.981293
# Epoch 70 Epoch Loss 8.519626
# Time taken for 1 epoch 1.1132922172546387 sec
#
# Epoch 71 Batch 0 Batch Loss 0.1225
# Total Loss 429.819672
# Epoch 71 Epoch Loss 8.596394
# Time taken for 1 epoch 1.9589204788208008 sec
#
# Epoch 72 Batch 0 Batch Loss 0.1227
# Total Loss 424.027435
# Epoch 72 Epoch Loss 8.480549
# Time taken for 1 epoch 1.1163311004638672 sec
#
# Epoch 73 Batch 0 Batch Loss 0.1231
# Total Loss 421.949554
# Epoch 73 Epoch Loss 8.438992
# Time taken for 1 epoch 1.119478464126587 sec
#
# Epoch 74 Batch 0 Batch Loss 0.1217
# Total Loss 422.362549
# Epoch 74 Epoch Loss 8.447251
# Time taken for 1 epoch 1.171929121017456 sec
#
# Epoch 75 Batch 0 Batch Loss 0.1335
# Total Loss 424.891785
# Epoch 75 Epoch Loss 8.497836
# Time taken for 1 epoch 1.1177613735198975 sec
#
# Epoch 76 Batch 0 Batch Loss 0.1185
# Total Loss 414.985260
# Epoch 76 Epoch Loss 8.299706
# Time taken for 1 epoch 2.077620267868042 sec
#
# Epoch 77 Batch 0 Batch Loss 0.1228
# Total Loss 415.339325
# Epoch 77 Epoch Loss 8.306787
# Time taken for 1 epoch 1.2631077766418457 sec
#
# Epoch 78 Batch 0 Batch Loss 0.1289
# Total Loss 417.809723
# Epoch 78 Epoch Loss 8.356194
# Time taken for 1 epoch 1.1683588027954102 sec
#
# Epoch 79 Batch 0 Batch Loss 0.1273
# Total Loss 414.217499
# Epoch 79 Epoch Loss 8.284350
# Time taken for 1 epoch 1.110422134399414 sec
#
# Epoch 80 Batch 0 Batch Loss 0.1205
# Total Loss 417.328583
# Epoch 80 Epoch Loss 8.346572
# Time taken for 1 epoch 1.2627995014190674 sec
#
# Epoch 81 Batch 0 Batch Loss 0.1185
# Total Loss 414.274475
# Epoch 81 Epoch Loss 8.285489
# Time taken for 1 epoch 1.9014508724212646 sec
#
# Epoch 82 Batch 0 Batch Loss 0.1175
# Total Loss 406.668457
# Epoch 82 Epoch Loss 8.133369
# Time taken for 1 epoch 1.1104991436004639 sec
#
# Epoch 83 Batch 0 Batch Loss 0.1114
# Total Loss 411.214508
# Epoch 83 Epoch Loss 8.224290
# Time taken for 1 epoch 1.1155929565429688 sec
#
# Epoch 84 Batch 0 Batch Loss 0.1261
# Total Loss 415.774231
# Epoch 84 Epoch Loss 8.315485
# Time taken for 1 epoch 1.2064697742462158 sec
#
# Epoch 85 Batch 0 Batch Loss 0.1187
# Total Loss 413.118896
# Epoch 85 Epoch Loss 8.262378
# Time taken for 1 epoch 1.1147181987762451 sec
#
# Epoch 86 Batch 0 Batch Loss 0.1216
# Total Loss 414.892548
# Epoch 86 Epoch Loss 8.297851
# Time taken for 1 epoch 2.051206350326538 sec
#
# Epoch 87 Batch 0 Batch Loss 0.1165
# Total Loss 411.654602
# Epoch 87 Epoch Loss 8.233092
# Time taken for 1 epoch 1.1344578266143799 sec
#
# Epoch 88 Batch 0 Batch Loss 0.1113
# Total Loss 407.801880
# Epoch 88 Epoch Loss 8.156037
# Time taken for 1 epoch 1.2653863430023193 sec
#
# Epoch 89 Batch 0 Batch Loss 0.1211
# Total Loss 407.105408
# Epoch 89 Epoch Loss 8.142108
# Time taken for 1 epoch 1.123898983001709 sec
#
# Epoch 90 Batch 0 Batch Loss 0.1225
# Total Loss 422.524719
# Epoch 90 Epoch Loss 8.450495
# Time taken for 1 epoch 1.1159172058105469 sec
#
# Epoch 91 Batch 0 Batch Loss 0.1236
# Total Loss 421.353394
# Epoch 91 Epoch Loss 8.427068
# Time taken for 1 epoch 1.8729252815246582 sec
#
# Epoch 92 Batch 0 Batch Loss 0.1180
# Total Loss 412.959381
# Epoch 92 Epoch Loss 8.259188
# Time taken for 1 epoch 1.1191389560699463 sec
#
# Epoch 93 Batch 0 Batch Loss 0.1177
# Total Loss 404.662445
# Epoch 93 Epoch Loss 8.093249
# Time taken for 1 epoch 1.1096758842468262 sec
#
# Epoch 94 Batch 0 Batch Loss 0.1170
# Total Loss 400.317474
# Epoch 94 Epoch Loss 8.006350
# Time taken for 1 epoch 1.114238977432251 sec
#
# Epoch 95 Batch 0 Batch Loss 0.1097
# Total Loss 398.950134
# Epoch 95 Epoch Loss 7.979002
# Time taken for 1 epoch 1.1083564758300781 sec
#
# Epoch 96 Batch 0 Batch Loss 0.1186
# Total Loss 401.967896
# Epoch 96 Epoch Loss 8.039358
# Time taken for 1 epoch 1.9013733863830566 sec
#
# Epoch 97 Batch 0 Batch Loss 0.1138
# Total Loss 395.469238
# Epoch 97 Epoch Loss 7.909385
# Time taken for 1 epoch 1.1406257152557373 sec
#
# Epoch 98 Batch 0 Batch Loss 0.1143
# Total Loss 400.717560
# Epoch 98 Epoch Loss 8.014351
# Time taken for 1 epoch 1.1431398391723633 sec
#
# Epoch 99 Batch 0 Batch Loss 0.1165
# Total Loss 401.162048
# Epoch 99 Epoch Loss 8.023241
# Time taken for 1 epoch 1.142608642578125 sec
#
# Epoch 100 Batch 0 Batch Loss 0.1146
# Total Loss 402.329987
# Epoch 100 Epoch Loss 8.046599
# Time taken for 1 epoch 1.1096627712249756 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Test Stage

# %% [markdown]
# ### Evaluate random image

# %%
# Remove <start>, <end> and <pad> marks from the predicted sequence
def clean_caption(caption):
    return [item for item in caption if item not in ['<start>', '<end>', '<pad>']]

# %%
test_img_name = random.choice(image_filenames_train)

# %%
# Get captions from a test image
def get_caption(img):
    # Add image to an array to simulate batch size of 1
    features = encoder(tf.expand_dims(img, 0))

    caption = []
    dec_input = tf.expand_dims([], 0)

     # Inputs the image embedding into the trained LSTM layer and predicts the first word of the sequence.
    # The output, hidden and cell states are passed again to the LSTM to generate the next word.
    # The iteration is repeated until the caption does not reach the max length.
    state = None
    for i in range(1, max_caption_length):
        predictions, memory_state, carry_state = \
            decoder(dec_input, features, omit_features=i > 1, initial_state=state)

        # Takes maximum index of predictions
        word_index = np.argmax(predictions.numpy().flatten())

        caption.append(tokenizer.index_word[word_index])

        dec_input = tf.expand_dims([word_index], 0)
        state = [memory_state, carry_state]

    # Filter caption
    return clean_caption(caption)

raw_img = load_image(test_img_name)[0]
img = images_dict[test_img_name]
captions = images_captions_dict[test_img_name]

plt.imshow(raw_img)

print("Real captions")
for caption in captions:
    print(caption)

print("Esimated caption")
estimated_caption = get_caption(img)
print(estimated_caption)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Real captions
# <start> A man in an orange hat pulls a cigarette out of a box . <end>
# <start> A man reaches into his pack for a cigarette . <end>
# <start> A man takes out a cigarette . <end>
# <start> A man with a orange hat and a brown jacket has a cigarette in his mouth . <end>
# <start> There is a man with a brown hat lighting a cigarette . <end>
# Esimated caption
# ['a', 'man', 'reaches', 'into', 'his', 'pack', 'for', 'a', 'cigarette']

# %% [markdown]
# ### Evaluate dataset using BLEU

# %%
def get_caption(img):
    # Add image to an array to simulate batch size of 1
    features = encoder(tf.expand_dims(img, 0))

    caption = []
    dec_input = tf.expand_dims([], 0)

    state = None
    for i in range(1, max_caption_length):
        predictions, memory_state, carry_state = \
            decoder(dec_input, features, omit_features=i > 1, initial_state=state)

        word_index = np.argmax(predictions.numpy().flatten())

        caption.append(tokenizer.index_word[word_index])

        dec_input = tf.expand_dims([word_index], 0)
        state = [memory_state, carry_state]

    # Filter caption
    return clean_caption(caption)

actual, predicted = [], []

for test_img_name in image_filenames_test:
    img = images_dict[test_img_name]
    estimated_caption = get_caption(img)

    captions = [clean_caption(caption.split()) for caption in images_captions_dict[test_img_name]]

    # store actual and predicted
    actual.append(captions)
    predicted.append(estimated_caption)

# Print BLEU score
print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
# Out:
# BLEU-1: 0.339424
# BLEU-2: 0.149234
